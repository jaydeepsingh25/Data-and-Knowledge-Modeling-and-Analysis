# %% [markdown]
# <h2><center>ASSIGNMENT 2</center></h2>
# <h2><center>DEEP ASHISH JARIWALA, JAYDEEP SINGH</center></h2>
# <h2><center>GROUP - 31</center></h2>
# <h2><center>Q: CM6</center></h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

classifier = ['Decision Tree','Random Forest', 'Gradient Boosting', 'Naive Bayes']

## seed dataset
## accuracy on validation set
acc_seed_val = [91.75, 91.75, 91.71, 92.33]
## accuracy on test set
acc_seed_test = [90, 90, 95, 92.5]
## average mean-fit time
time_seed = [9.8, 107.9, 176, 0.7578]


## covid dataset
## accuracy on validation set
acc_covid_val = [66.21, 66.88, 66.88, 64.71]
## accuracy on test set
acc_covid_test = [66.72, 67.68, 66.99, 66.64]
## average mean-fit time
time_covid = [98.3, 1177, 7212, 72.39]

# %% [markdown]
# ## SEED DATASET ALL ALGORITHM COMPARISIONS

# %%
fig = plt.figure(figsize=(15,8))

plt.subplot(221)
plt.title("SEED DATASET VALIDATION ACCURACY")
sns.pointplot(x=classifier, y = acc_seed_val)
plt.xlabel("Classification Algorithm")
plt.ylabel("Accuracy %")

plt.subplot(222)
plt.title("SEED DATASET TEST ACCURACY")
sns.pointplot(x=classifier, y = acc_seed_test)
plt.xlabel("Classification Algorithm")
plt.ylabel("Accuracy %")

plt.subplot(223)
plt.title("SEED DATASET COMPUTATION TIME")
sns.pointplot(x=classifier, y = time_seed)
plt.xlabel("Classification Algorithm")
plt.ylabel("Mean fit time--millisecond")
fig.tight_layout()

# %% [markdown]
# <table>
#   <tr>
#     <th>Classifier</th>
#     <th>Best Parameters</th>
#     <th>Average validation Accuracy</th>
#     <th>Test Accuracy</th>
#     <th>mean fit time(computation time)</th>
#   </tr>
#   <tr>
#     <td>Decision Tree</td>
#     <td>Max_depth = 5</td>
#     <td>91.75%</td>
#     <td>90%</td>
#     <td>9.8 ms</td>
#    </tr>
# <tr>
#     <td>Random Forest Classifier</td>
#     <td>Max_depth = 5, n_estimators = 10</td>
#     <td>91.75%</td>
#     <td>90%</td>
#     <td>107.9 ms</td>
#    </tr>
# <tr>
#     <td>Gradient Boosting Classifier</td>
#     <td>n_estimators = 150</td>
#     <td>91.71%</td>
#     <td>95%</td>
#     <td>176 ms</td>
#    </tr>
#     <tr>
#     <td>Naive bayes</td>
#     <td>var_smoothing = 0.001</td>
#     <td>92.33%</td>
#     <td>92.5%</td>
#     <td>0.7578 ms</td>
#    </tr>
# </table>

# %% [markdown]
# <p>
# <ul>
# <li><b>Accuracy</b>:
# <div>
#     Naive Bayes Classifier has higher accuracy on validation set than any of the tree based models.
# On the test set, Naive Bayes performs fairly good with accuracy higher than Decision Trees and Random Forests.This is because in seeds dataset, all the the features are numerical in nature and normally distributed. Moreover, Random forests and Boosting require a large amount of data to work well, whereas the seed dataset size is relatively small.
#     </div>
#     <div>
#     The seeds dataset has noisy continous features, and the Naive Bayes algorithm is robust to noise in the data, whereas Decision trees often tend to learn from the noise in the data resulting in overfitting.
#     </div>
#     </li>
# <li>
# <b>Time</b>:
#     <div>
# Naive Bayes clearly outperforms tree based models in the time taken to fit the model. The Reason being it is a fairly simple model which is easy to train compared to tree based models.
#     </div>
#         </li>
# </ul>
# </p>

# %% [markdown]
# ### Comparison of learned NB parameters and Decision Trees

# %%
# Values taken from CM4 output

class_count_ = [52, 55, 51]

class_prior_ = [0.32911392, 0.34810127, 0.32278481]

sigma_ = [
       [1.47875621, 0.33480059, 0.00900017, 0.06201897, 0.04070806, 1.68445565, 0.07707704],
       [1.92666615, 0.34365953, 0.0089558 , 0.06643817, 0.04222245, 1.45014661, 0.05757769],
       [0.48677014, 0.11978259, 0.0091581 , 0.02713382, 0.0283718 ,1.60318485, 0.03533927]]

theta_ = [
       [14.28269231, 14.26884615,  0.88000577,  5.49938462,  3.24076923, 2.75613846,  5.08213462],
       [18.47509091, 16.20672727,  0.88255818,  6.18145455,  3.68961818, 3.66296364,  6.04552727],
       [11.92980392, 13.26666667,  0.85106078,  5.23572549,  2.86598039, 4.59947059,  5.11607843]]

# %%
arr = theta_
df_1 = pd.DataFrame(arr, index = ['class1','class2','class3'], columns = ['area','perimeter','compactness','length_kernel','width_kernel','asymmetry_coeff','length_of_kernel_groove'])
df_1.reset_index(level=0, inplace=True)

arr = sigma_
df_2 = pd.DataFrame(arr, index = ['class1','class2','class3'], columns = ['area','perimeter','compactness','length_kernel','width_kernel','asymmetry_coeff','length_of_kernel_groove'])
df_2.reset_index(level=0, inplace=True)

# %%
fig = plt.figure(figsize=(15,10))

plt.subplot(231)
plt.title("Mean of length_of_kernel_groove")
sns.barplot(x = 'index', y='length_of_kernel_groove', data = df_1, palette = 'dark')

plt.subplot(232)
plt.title("Mean of perimeter")
sns.barplot(x = 'index', y='perimeter', data = df_1, palette = 'dark')

plt.subplot(233)
plt.title("Mean of asymmetry_coeff")
sns.barplot(x = 'index', y='asymmetry_coeff', data = df_1, palette = 'dark')

plt.subplot(234)
plt.title("Variance of length_of_kernel_groove")
sns.barplot(x = 'index', y='length_of_kernel_groove', data = df_2, palette = 'dark')

plt.subplot(235)
plt.title("Variance of perimeter")
sns.barplot(x = 'index', y='perimeter', data = df_2, palette = 'dark')

plt.subplot(236)
plt.title("Variance of asymmetry_coeff")
sns.barplot(x = 'index', y='asymmetry_coeff', data = df_2, palette = 'dark')
# Out:
# <AxesSubplot:title={'center':'Variance of asymmetry_coeff'}, xlabel='index', ylabel='asymmetry_coeff'>

# %% [markdown]
# On Analysing the learned parameters of NB and the rules of the decison tree, we can list the following observations about the data:
# <ul>
#     <li>
#       <b>The dataset is fairly balanced with almost equal number of samples present in each class</b>
#       <br>This is indicated by the parameters class_count_ with value = [52,51,51] and class_prior = [0.32911392, 0.34810127, 0.32278481].
#     <br>Even the decision tree Root Node confirms the same which shows the number of samples in each class as [52,51,51]
#     </li>
#     <li>
#     <b>The samples belonging to Class 2 have a much greater length of kernel groove as compared to the Class 1 and Class 3</b>
#     <br>As indicated by the parameter theta_(mean of each feature per class), mean length_of_kernel_groove for class 2 is 6.05 whereas for class 1 and 3 it is 5.08 and 5.11 respectively.
#     <br>
#     Similar behaviour is confirmed by decision trees as the deciding factor at the root node is the length_of_kernel_groove, and if it greater than 5.573 the samples in the right subtree contains mainly the Class2 samples wheares the left subtree(length less than 5.573) contains Class 1 and Class 3 Samples
#     </li>
#     <li>
#     <b>The samples belonging to Class 1 have a higher value of perimeter compared to samples in Class 3</b>
#     <br>As indicated by the parameter theta_(mean of each feature per class), mean perimeter value for Class 1 is 14.26 whereas for Calss 3 it is 13.26.
#     <br>
#     It is observed that in the left subtree, there is a decision node which seperates the values based on the perimeter and the values greater than 13.8 mainly belong to class 1, and the samples with perimeter values less than 13.8 contain Class 3 samples in majority.
#     </li>
#     <li>
#     <b>The samples belonging to Class 3 have a higher value of assymetry_coeff compared to samples in Class 1 and 2</b>
#     <br>As indicated by the parameter theta_(mean of each feature per class), mean assymetry_coeff value for Class 3 is 4.599 whereas for Class 1 and Class 2 it is 2.75 and 3.66 respectively.
#     <br>
#     The decison tree also uses assymetry_coeff to seperate the samples in into classes at multiple places in left and right subtree
#     </li>
#      <li>
#     <b>Among all the classes, samples of class 3 have minimum variance in the perimeter and length_of_kernel_groove values</b>
#     </li>
# </ul>

# %% [markdown]
# ## COVID DATASET ALL ALGORITHM COMPARISIONS

# %%
fig = plt.figure(figsize=(15,8))

plt.subplot(221)
plt.title("COVID DATASET VALIDATION ACCURACY")
sns.pointplot(x=classifier, y = acc_covid_val)
plt.xlabel("Classification Algorithm")
plt.ylabel("Accuracy %")

plt.subplot(222)
plt.title("COVID DATASET TEST ACCURACY")
sns.pointplot(x=classifier, y = acc_covid_test)
plt.xlabel("Classification Algorithm")
plt.ylabel("Accuracy %")

plt.subplot(223)
plt.title("COVID DATASET COMPUTATION TIME")
sns.pointplot(x=classifier, y = time_covid)
plt.xlabel("Classification Algorithm")
plt.ylabel("Mean fit time--millisecond")
fig.tight_layout()

# %% [markdown]
# <table>
#   <tr>
#     <th>Classifier</th>
#     <th>Best Parameters</th>
#     <th>Average validation Accuracy</th>
#     <th>Test Accuracy</th>
#     <th>mean fit time(computation time)</th>
#   </tr>
#   <tr>
#     <td>Decision Tree</td>
#     <td>Max_depth = 10</td>
#     <td>66.21%</td>
#     <td>66.72%</td>
#     <td>98.3 ms</td>
#    </tr>
# <tr>
#     <td>Random Forest Classifier</td>
#     <td>Max_depth = 10, n_estimators = 150</td>
#     <td>66.88%</td>
#     <td>67.68%</td>
#     <td>1177 ms</td>
#    </tr>
# <tr>
#     <td>Gradient Boosting Classifier</td>
#     <td>n_estimators = 50</td>
#     <td>66.88%</td>
#     <td>66.99%</td>
#     <td>7212 ms</td>
#    </tr>
#      <tr>
#     <td>Naive Bayes</td>
#     <td>var_smoothing = 0.1</td>
#     <td>64.71%</td>
#     <td>66.64%</td>
#     <td>72.39 ms</td>
#    </tr>
# </table>

# %% [markdown]
# <p>
# <ul>
# <li><b>Accuracy</b>:
# <div>
#     The Gaussian Naive Bayes Classifier has lesser validation and test accuracy than any of the tree-based models. This is because the Gaussian method is typically used to deal with continuous data, and the values are assumed to be distributed according to a normal distribution whereas most of the values in the covid dataset are categorical in nature, which have been encoded by various techniques and moreover features lack mutual independence among them. Thus it can be infered that Gaussian Naive Bayes is not an ideal model to train this type of data.
#     <p>
#         Also, an intersting point here is that even though Decision Trees have a higher validation accuracy than the Naive Bayes Classifier, the performance on the test set is almost similar for both of them, this is because Navie Bayes is a high bias/low variance classifier, whereas Decision trees are low bias/high variance classifiers. They can create learners that do not generalize data well and are prone to overfitting.
#     </p>
#     </div>
#     </li>
# <li>
# <b>Time</b>:
#     <div>
#        Even for a complex dataset like Covid, the time taken by the Naive Bayes Classifier is significantly less compared to other models. This is because of the simplicity of the model. Random Forests and Boosting generally become slower if a large number of estimators are used.
#     </div>
#         </li>
# </ul>
# </p>

# %% [markdown]
# ### Comparison of learned NB parameters and Decision Trees

# %%
# Values taken from CM5 output

class_count_ = [4172, 4191, 4166]

classes_ = ['Fatal','Not Resolved','Resolved']

class_prior_ = [0.33298747,0.33450395,0.33250858]

theta_ = [[ 0.00000000e+00,  4.79386385e-01,  7.83796740e-02 , 1.03547459e-01,
   7.27468840e-01,  1.27037392e-02,  0.00000000e+00 , 7.19079578e-04,
   1.43815916e-03,  8.38926174e-03,  4.79386385e-04 , 9.58772771e-03,
   1.17449664e-02,  4.07478428e-02,  0.00000000e+00 , 2.39693193e-04,
   2.80441035e-02,  9.58772771e-02,  2.39693193e-04 , 7.67018217e-02,
   2.39693193e-04,  2.56471716e-02,  6.78331735e-02 , 0.00000000e+00,
   2.39693193e-04,  1.19846596e-03,  5.51294343e-03 , 6.23202301e-03,
   2.39693193e-04,  6.23202301e-03,  9.82742090e-03 , 6.23202301e-03,
   7.19079578e-04,  5.12943432e-02, 3.83509108e-03 , 1.91754554e-03,
   3.83748802e-01 , 3.40364334e-02,  4.81783317e-02 , 4.88974113e-02,
   7.56951103e-01 , 7.82790029e+00,  4.37228728e+01 ,-7.94726359e+01],
 [ 0.00000000e+00 , 4.94392746e-01,  3.55762348e-01 , 1.32188022e-01,
   1.87306132e-01 , 9.54426151e-03,  0.00000000e+00 , 0.00000000e+00,
   5.72655691e-03 , 1.43163923e-03,  6.44237652e-03,  1.09759007e-02,
   2.50536865e-02 , 3.55523741e-02,  1.19303269e-03,  4.77213076e-04,
   2.48150799e-02 , 2.00429492e-01,  2.38606538e-04,  7.27749940e-02,
   9.54426151e-04 , 3.53137676e-02,  4.41422095e-02,  1.90885230e-03,
   2.38606538e-04 , 2.38606538e-03,  3.81770461e-03,  5.48795037e-03,
   1.43163923e-03 , 3.81770461e-03,  6.44237652e-03,  5.01073729e-03,
   6.91958960e-03 , 3.31663088e-02,  7.87401575e-03,  3.57909807e-03,
   3.48365545e-01  ,2.67239322e-02,  2.43378669e-02,  2.55308995e-02,
   2.18563589e-01  ,3.98377476e+00,  4.37715009e+01, -7.96239586e+01],
 [ 2.40038406e-04  ,4.98799808e-01,  1.62265963e-01,  2.08353337e-01,
   1.72827652e-01  ,1.72827652e-02 , 7.20115218e-04,  2.40038406e-03,
   6.96111378e-03  ,2.64042247e-03 , 4.32069131e-03,  1.10417667e-02,
   1.41622660e-02  ,3.12049928e-02 , 9.60153625e-04,  2.16034566e-03,
   1.82429189e-02  ,2.10033605e-01 , 9.60153625e-04,  8.97743639e-02,
   2.40038406e-04 , 3.16850696e-02 , 4.77676428e-02,  2.16034566e-03,
   1.20019203e-03 , 2.40038406e-03 , 6.72107537e-03,  4.08065290e-03,
   2.40038406e-04 , 6.72107537e-03 , 7.44119059e-03,  4.08065290e-03,
   2.64042247e-03 , 2.80844935e-02 , 3.84061450e-03,  1.20019203e-03,
   3.08689390e-01 , 3.09649544e-02 , 4.94479117e-02,  4.34469515e-02,
   2.04512722e-01 , 3.71747480e+00 , 4.37283864e+01 ,-7.95805776e+01]]

sigma_ = [
[0.68274483, 0.93231991, 0.75498113, 0.77557021, 0.88100276, 0.69528718,
  0.68274483, 0.68346339, 0.68418092, 0.69106371, 0.68322399, 0.69224063,
  0.69435185, 0.72183229, 0.68274483, 0.68298447, 0.71000246, 0.76942965,
  0.68298447, 0.75356348, 0.68298447, 0.70773422, 0.74597666, 0.68274483,
  0.68298447, 0.68394186, 0.68822738, 0.68893801, 0.68298447, 0.68893801,
  0.69247567, 0.68893801, 0.68346339, 0.73140806, 0.68656521, 0.6846587,
  0.91923049, 0.71562278, 0.72860201, 0.72925128, 0.86672096, 1.99636717,
  1.21373349, 3.23445524],
 [0.68274483, 0.93271339, 0.91194033, 0.79745918, 0.83496737, 0.692198,
  0.68274483, 0.68274483, 0.68843859, 0.68417442, 0.6891457,  0.69360026,
  0.70717083, 0.71703323, 0.68393644, 0.68322181, 0.70694412, 0.84300234,
  0.68298338, 0.75022362, 0.68369834, 0.71681153, 0.7249385,  0.68465004,
  0.68298338, 0.6851252 , 0.68654796, 0.68820266, 0.68417442, 0.68654796,
  0.6891457,  0.68773046, 0.68961654, 0.71481113, 0.69055685, 0.68631112,
  0.90975182, 0.70875459, 0.70649036, 0.7076239,  0.85353838, 5.14824153,
  1.32930538, 3.23517656],
 [0.68298481, 0.93274339, 0.81868055, 0.84768705, 0.82570308, 0.6997289,
  0.68346443, 0.68513945, 0.68965749, 0.68537828, 0.68704685, 0.69366468,
  0.69670653, 0.71297607, 0.68370406, 0.68490051, 0.70065494, 0.84866432,
  0.68370406, 0.76445976, 0.68298481, 0.71342596, 0.72823072, 0.68490051,
  0.68394358, 0.68513945, 0.68942073, 0.68680883, 0.68298481, 0.68942073,
  0.69013065, 0.68680883, 0.68537828, 0.71004058, 0.68657069, 0.68394358,
  0.89614508, 0.71275096, 0.72974765, 0.72430414, 0.8454321,  4.80815718,
  1.19108762, 3.08206284]]

# %%
arr = [[7.82790029e+00,7.83796740e-02,7.56951103e-01],[3.98377476e+00,3.55762348e-01, 2.18563589e-01],[3.71747480e+00,1.62265963e-01,2.04512722e-01]]
df_3 = pd.DataFrame(arr, index = classes_, columns = ['Age_group','Case_AcquisitionInfo_MISSING_INFORMATION','Outbreak_Related_Yes'])
df_3.reset_index(level=0, inplace=True)

arr = [[1.99636717,0.75498113,0.86672096],[5.14824153,0.91194033,0.85353838],[4.80815718,0.81868055,0.8454321]]
df_4 = pd.DataFrame(arr, index = classes_, columns = ['Age_group','Case_AcquisitionInfo_MISSING_INFORMATION','Outbreak_Related_Yes'])
df_4.reset_index(level=0, inplace=True)

# %%
fig = plt.figure(figsize=(15,10))

plt.subplot(231)
plt.title("Mean of Age_group")
sns.barplot(x = 'index', y='Age_group', data = df_3, palette = 'dark')

plt.subplot(232)
plt.title("Mean of Case_AcquisitionInfo_MISSING_INFORMATION")
sns.barplot(x = 'index', y='Case_AcquisitionInfo_MISSING_INFORMATION', data = df_3, palette = 'dark')

plt.subplot(233)
plt.title("Mean of Outbreak_Related_Yes")
sns.barplot(x = 'index', y='Outbreak_Related_Yes', data = df_3, palette = 'dark')

plt.subplot(234)
plt.title("Variance of Age_group")
sns.barplot(x = 'index', y='Age_group', data = df_4, palette = 'dark')

plt.subplot(235)
plt.title("Variance of Case_AcquisitionInfo_MISSING_INFORMATION")
sns.barplot(x = 'index', y='Case_AcquisitionInfo_MISSING_INFORMATION', data = df_4, palette = 'dark')

plt.subplot(236)
plt.title("Variance of Outbreak_Related_Yes")
sns.barplot(x = 'index', y='Outbreak_Related_Yes', data = df_4, palette = 'dark')
# Out:
# <AxesSubplot:title={'center':'Variance of Outbreak_Related_Yes'}, xlabel='index', ylabel='Outbreak_Related_Yes'>

# %% [markdown]
# On Analysing the learned parameters of NB and the rules of the decison tree, we can list the following observations about the data:
# <ul>
#     <li>
#       <b>The dataset is fairly balanced with almost equal number of samples present in each class</b>
#       <br>This is indicated by the parameters class_count_ with value = [4172, 4191, 4166] and class_prior = [0.33298747 , 0.33450395, 0.33250858].
#     <br>Even the decision tree Root Node confirms the same which shows the number of samples in each class as [4172, 4191, 4166]
#     </li>
#     <li>
#     <b>The samples belonging to Fatal Class have a much greater Age as compared to the Not Resolved and Resolved</b>
#     <br>As indicated by the parameter theta_(mean of each feature per class), mean Age_Group for Fatal Class is 7.82 whereas for classes Not Resolved and Resolved it is 3.98 and 3.71. i.e people above the age 70's have a greater probability of having Fatal Outcome
#     <br>
#     Similar behaviour is confirmed by decision trees as the deciding factor at the root node is the Age_Group, and if it greater than 6.5 the samples in the right subtree contains mainly the Fatal samples wheares the left subtree(Age_Group less than 6.5) contains Resolved and Not Resolved Samples
#     </li>
#     <li>
#     <b>Most of the samples with Outbreak_Related = Yes belong to Fatal Category</b>
#     <br>This is indicated by the plot above where the samples in Fatal Category have higher mean value of encoded variable Outbreak_Related_Yes compared to the samples in the other two classes.
#     <br>
#     Even in decision tree this feature is used a decision node to split the samples in the right subtree, where majority of Fatal samples are seperated from the other two classes.
#     </li>
# </ul>
