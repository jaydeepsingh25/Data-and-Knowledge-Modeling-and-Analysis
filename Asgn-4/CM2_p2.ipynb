# %% [markdown]
# <p>All the necessary code blocks used to achieve the best resulting fully connected DNN for this classification problem.</p>
# <ul>
#     <li>SELECTING BEST ARCHITECTURE</li>
#     <li>SELECTING BEST ACTIVATION FUNCTION</li>
#     <li>SELECTING BEST OPTIMIZATION</li>
#     <li>SELECTING BEST LEARNING RATE AND DROP OUT</li>
# </ul>

# %% [markdown]
# # CODE BLOCKS TO GET BEST ACTIVATION FUNCTION FOR OUR MODEL

# %% [markdown]
# <p>In this part we are trying  6 different activation functions and the final summary is reported in CM3</p>

# %% [markdown]
# ### PREPARATION OF DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization

from numpy.random import seed
seed(20)
tf.random.set_seed(13)

# %%
dataset = pd.read_csv("COVID_dataset_train.csv")

# %%
# replacing NaN in Outbreak_Related with NO 
dataset['Outbreak_Related'] = dataset['Outbreak_Related'].fillna("No") 

# Dropping NaN values in Age_Group, Test_reported_date and specimen_date
dataset = dataset.dropna()

# %%
dataset.Accurate_Episode_Date = pd.to_datetime(dataset.Accurate_Episode_Date)
dataset.Case_Reported_Date = pd.to_datetime(dataset.Case_Reported_Date)
dataset.Test_Reported_Date = pd.to_datetime(dataset.Test_Reported_Date)
dataset.Specimen_Date = pd.to_datetime(dataset.Specimen_Date)

dataset = dataset.drop(['Test_Reported_Date', 'Specimen_Date'],axis=1)

# %%
dataset.Case_Reported_Date = list(map(lambda x: x.timestamp(),dataset.Case_Reported_Date))
dataset.Accurate_Episode_Date = list(map(lambda x: x.timestamp(),dataset.Accurate_Episode_Date))

# %%
## encoding of target variable
dataset_target = dataset['Outcome1']
dataset_target = pd.DataFrame(dataset_target, columns = ['Outcome1'])

categorical_cols = ['Outcome1']

# Create the encoder.
encoder_1 = OneHotEncoder(categories = "auto", handle_unknown="error", sparse = False)

# Fit and transform encoder to X
array_hot_encoded_1 = encoder_1.fit_transform(dataset_target)

# convert it to a Data Frame
data_hot_encoded_1 = pd.DataFrame(array_hot_encoded_1, index=dataset_target.index)

# set column names of encoded dataframe
data_hot_encoded_1.columns = encoder_1.get_feature_names(categorical_cols)

dataset_target_1 = data_hot_encoded_1

# %%
## encoding of features
dataset_features = dataset.drop(['Outcome1'], axis = 1)

dataset_features['Age_Group'] = dataset_features['Age_Group'].replace({'<20': 1, '20s': 2, '30s': 3 , '40s': 4, '50s': 5, '60s': 6, '70s': 7, '80s': 8, '90s': 9})

categorical_cols = ['Client_Gender','Case_AcquisitionInfo','Reporting_PHU_City','Outbreak_Related']

# Create the encoder.
encoder = OneHotEncoder(categories = "auto", handle_unknown="error", sparse = False)

# Fit and transform encoder to X
array_hot_encoded = encoder.fit_transform(dataset_features[categorical_cols])

# convert it to a Data Frame
data_hot_encoded = pd.DataFrame(array_hot_encoded, index=dataset.index)

# set column names of encoded dataframe
data_hot_encoded.columns = encoder.get_feature_names(categorical_cols)

# concatenate other columns with the encoded columns to get the final datset
data_other_cols = dataset_features.drop(columns=categorical_cols)
dataset_temp = pd.concat([data_hot_encoded, data_other_cols], axis=1)
dataset_features = dataset_temp

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset_features, dataset_target_1, test_size = 0.10, random_state = 360)

# %%
# X_train = dataset_features
# y_train = dataset_target_1

# %%
from sklearn.preprocessing import StandardScaler
numeric_columns = ['Reporting_PHU_Longitude', 'Reporting_PHU_Latitude','Case_Reported_Date', 'Accurate_Episode_Date']

sc = StandardScaler()

X_train_scaled = X_train.copy()


X_train_scaled[numeric_columns] = sc.fit_transform(X_train[numeric_columns])

# %%
X_test_scaled = X_test.copy()
X_test_scaled[numeric_columns] = sc.transform(X_test[numeric_columns])

# %% [markdown]
# ## ACTIVATION FUNCTION 1: RELU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow as tf

# INITIALING ANN
ann = tf.keras.models.Sequential()

# ADDING INPUT LAYER AND FIRST HIDDEN LAYER
ann.add(tf.keras.layers.Dense(units = 112, activation='relu'))
ann.add(Dropout(0.05))

# ADDING SECOND HIDDEN LAYER
ann.add(tf.keras.layers.Dense(units=448, activation='relu', kernel_regularizer=l2(0.001)))

# ADDING THIRD HIDDEN LAYER
ann.add(tf.keras.layers.Dense(units=56, activation='relu'))

# ADDING OUTPUT LAYER
ann.add(tf.keras.layers.Dense(units=3, activation='softmax'))

ann.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='val_loss', patience = 10)

fitted_model = ann.fit(X_train_scaled, y_train, validation_split = 0.15, callbacks = [callback], epochs= 400, verbose=1)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 351/351 [==============================] - 1s 2ms/step - loss: 0.5449 - accuracy: 0.8213 - val_loss: 0.4183 - val_accuracy: 0.8706
# Epoch 2/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.3929 - accuracy: 0.8782 - val_loss: 0.3532 - val_accuracy: 0.8938
# Epoch 3/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.3487 - accuracy: 0.8871 - val_loss: 0.3303 - val_accuracy: 0.8928
# Epoch 4/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.3211 - accuracy: 0.8969 - val_loss: 0.2906 - val_accuracy: 0.9039
# Epoch 5/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.3103 - accuracy: 0.8980 - val_loss: 0.2977 - val_accuracy: 0.9004
# Epoch 6/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2943 - accuracy: 0.9030 - val_loss: 0.3530 - val_accuracy: 0.8665
# Epoch 7/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2810 - accuracy: 0.9058 - val_loss: 0.2707 - val_accuracy: 0.9085
# Epoch 8/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2809 - accuracy: 0.9043 - val_loss: 0.2791 - val_accuracy: 0.9009
# Epoch 9/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2722 - accuracy: 0.9083 - val_loss: 0.2759 - val_accuracy: 0.9065
# Epoch 10/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2714 - accuracy: 0.9075 - val_loss: 0.2715 - val_accuracy: 0.9039
# Epoch 11/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2631 - accuracy: 0.9102 - val_loss: 0.2621 - val_accuracy: 0.9065
# Epoch 12/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2619 - accuracy: 0.9103 - val_loss: 0.2614 - val_accuracy: 0.9080
# Epoch 13/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2584 - accuracy: 0.9119 - val_loss: 0.2752 - val_accuracy: 0.9009
# Epoch 14/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2605 - accuracy: 0.9085 - val_loss: 0.2618 - val_accuracy: 0.9085
# Epoch 15/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2531 - accuracy: 0.9125 - val_loss: 0.2727 - val_accuracy: 0.9019
# Epoch 16/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2524 - accuracy: 0.9151 - val_loss: 0.2490 - val_accuracy: 0.9115
# Epoch 17/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2527 - accuracy: 0.9114 - val_loss: 0.2601 - val_accuracy: 0.9100
# Epoch 18/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.9140 - val_loss: 0.3080 - val_accuracy: 0.8893
# Epoch 19/400
# 351/351 [==============================] - 1s 1ms/step - loss: 0.2465 - accuracy: 0.9156 - val_loss: 0.2732 - val_accuracy: 0.9014
# Epoch 20/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2452 - accuracy: 0.9166 - val_loss: 0.2657 - val_accuracy: 0.9075
# Epoch 21/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2437 - accuracy: 0.9151 - val_loss: 0.2651 - val_accuracy: 0.9039
# Epoch 22/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2436 - accuracy: 0.9155 - val_loss: 0.2551 - val_accuracy: 0.9100
# Epoch 23/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2416 - accuracy: 0.9176 - val_loss: 0.2544 - val_accuracy: 0.9070
# Epoch 24/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2428 - accuracy: 0.9167 - val_loss: 0.2761 - val_accuracy: 0.8984
# Epoch 25/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2432 - accuracy: 0.9157 - val_loss: 0.2504 - val_accuracy: 0.9085
# Epoch 26/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2401 - accuracy: 0.9174 - val_loss: 0.2509 - val_accuracy: 0.9115

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 112)               5824
# _________________________________________________________________
# dropout (Dropout)            (None, 112)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 448)               50624
# _________________________________________________________________
# dense_2 (Dense)              (None, 56)                25144
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 171
# =================================================================
# Total params: 81,763
# Trainable params: 81,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig = plt.figure(figsize=(18,5))
# summarize history for accuracy
plt.subplot(121)
plt.plot(fitted_model.history['accuracy'], c = 'green', label = 'train_acc')
plt.plot(fitted_model.history['val_accuracy'], c = 'red', label = 'val_acc')
plt.title('model-1 accuracy')
plt.ylabel('accuracy')
plt.legend()
plt.xlabel('epoch')

plt.subplot(122)
# summarize history for loss
plt.plot(fitted_model.history['loss'], label = 'train_loss')
plt.plot(fitted_model.history['val_loss'], label = 'val_loss')
plt.title('model-1 loss')
plt.ylabel('loss')
plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
print("Mean val acc:", np.mean(fitted_model.history['val_accuracy']))
print("Mean val loss:", np.mean(fitted_model.history['val_loss']))
print("Mean train acc:", np.mean(fitted_model.history['accuracy']))
print("Mean train loss:", np.mean(fitted_model.history['loss']))
# Out:
# Mean val acc: 0.9012600114712348
# Mean val loss: 0.2839101558694473
# Mean train acc: 0.9051691614664518
# Mean train loss: 0.2813888421425453

# %%
# FOR TESTING ON TRAINING SET

# check test set accuracy
results_train = ann.predict(X_test_scaled)

pred_values_train= []
for result in results_train:
    entry = [0,0,0]
    index = result.argmax()
    entry[index] = 1
    pred_values_train.append(entry)
    
from sklearn.metrics import confusion_matrix, accuracy_score
score = accuracy_score(y_test, pred_values_train)
print("test accuracy for model 1: ", score)
# Out:
# test accuracy for model 1:  0.9058020477815699

# %% [markdown]
# ## ACTIVATION FUNCTION 2: SIGMOID

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow as tf

# INITIALING ANN
ann_2 = tf.keras.models.Sequential()

# ADDING INPUT LAYER AND FIRST HIDDEN LAYER
ann_2.add(tf.keras.layers.Dense(units = 112, activation='sigmoid'))
ann_2.add(Dropout(0.05))

# ADDING SECOND HIDDEN LAYER
ann_2.add(tf.keras.layers.Dense(units=448, activation='sigmoid', kernel_regularizer=l2(0.001)))

# ADDING THIRD HIDDEN LAYER
ann_2.add(tf.keras.layers.Dense(units=56, activation='sigmoid'))

# ADDING OUTPUT LAYER
ann_2.add(tf.keras.layers.Dense(units=3, activation='softmax'))

ann_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='val_loss', patience = 10)

fitted_model_2 = ann_2.fit(X_train_scaled, y_train, validation_split = 0.15, callbacks = [callback], epochs= 400, verbose=1)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Layer dense_4 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 351/351 [==============================] - 1s 3ms/step - loss: 0.8393 - accuracy: 0.6364 - val_loss: 0.6155 - val_accuracy: 0.7801
# Epoch 2/400
# 351/351 [==============================] - ETA: 0s - loss: 0.5237 - accuracy: 0.82 - 1s 2ms/step - loss: 0.5194 - accuracy: 0.8307 - val_loss: 0.4718 - val_accuracy: 0.8180
# Epoch 3/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.4427 - accuracy: 0.8542 - val_loss: 0.4576 - val_accuracy: 0.8220
# Epoch 4/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3986 - accuracy: 0.8703 - val_loss: 0.3649 - val_accuracy: 0.8893
# Epoch 5/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3751 - accuracy: 0.8774 - val_loss: 0.4790 - val_accuracy: 0.8306
# Epoch 6/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3714 - accuracy: 0.8752 - val_loss: 0.5939 - val_accuracy: 0.7159
# Epoch 7/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3509 - accuracy: 0.8838 - val_loss: 0.3289 - val_accuracy: 0.8913
# Epoch 8/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3526 - accuracy: 0.8845 - val_loss: 0.3110 - val_accuracy: 0.9065
# Epoch 9/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3411 - accuracy: 0.8866 - val_loss: 0.3432 - val_accuracy: 0.8837
# Epoch 10/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3425 - accuracy: 0.8868 - val_loss: 0.3141 - val_accuracy: 0.8938
# Epoch 11/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3371 - accuracy: 0.8860 - val_loss: 0.3140 - val_accuracy: 0.8984
# Epoch 12/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3256 - accuracy: 0.8928 - val_loss: 0.3281 - val_accuracy: 0.8928
# Epoch 13/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3259 - accuracy: 0.8915 - val_loss: 0.3880 - val_accuracy: 0.8529
# Epoch 14/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3285 - accuracy: 0.8892 - val_loss: 0.3568 - val_accuracy: 0.8827
# Epoch 15/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3227 - accuracy: 0.8921 - val_loss: 0.3226 - val_accuracy: 0.8913
# Epoch 16/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3180 - accuracy: 0.8935 - val_loss: 0.2967 - val_accuracy: 0.9050
# Epoch 17/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3206 - accuracy: 0.8920 - val_loss: 0.3193 - val_accuracy: 0.8933
# Epoch 18/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3223 - accuracy: 0.8924 - val_loss: 0.3111 - val_accuracy: 0.8969
# Epoch 19/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3143 - accuracy: 0.8953 - val_loss: 0.2996 - val_accuracy: 0.8959
# Epoch 20/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3154 - accuracy: 0.8975 - val_loss: 0.3005 - val_accuracy: 0.8989
# Epoch 21/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3195 - accuracy: 0.8931 - val_loss: 0.2816 - val_accuracy: 0.9065
# Epoch 22/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3099 - accuracy: 0.8973 - val_loss: 0.2775 - val_accuracy: 0.9085
# Epoch 23/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3047 - accuracy: 0.8989 - val_loss: 0.2776 - val_accuracy: 0.9039
# Epoch 24/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3055 - accuracy: 0.8989 - val_loss: 0.2885 - val_accuracy: 0.9055
# Epoch 25/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2981 - accuracy: 0.9033 - val_loss: 0.2783 - val_accuracy: 0.9070
# Epoch 26/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2993 - accuracy: 0.9004 - val_loss: 0.2807 - val_accuracy: 0.9095
# Epoch 27/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3084 - accuracy: 0.8967 - val_loss: 0.3153 - val_accuracy: 0.8964
# Epoch 28/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3011 - accuracy: 0.8992 - val_loss: 0.2799 - val_accuracy: 0.9044
# Epoch 29/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2982 - accuracy: 0.9002 - val_loss: 0.2995 - val_accuracy: 0.8989
# Epoch 30/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2991 - accuracy: 0.9005 - val_loss: 0.3160 - val_accuracy: 0.8933
# Epoch 31/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3019 - accuracy: 0.8986 - val_loss: 0.3472 - val_accuracy: 0.8756
# Epoch 32/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2989 - accuracy: 0.8999 - val_loss: 0.2888 - val_accuracy: 0.9029

# %%
ann_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 112)               5824
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 112)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 448)               50624
# _________________________________________________________________
# dense_6 (Dense)              (None, 56)                25144
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 171
# =================================================================
# Total params: 81,763
# Trainable params: 81,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig = plt.figure(figsize=(18,5))
# summarize history for accuracy
plt.subplot(121)
plt.plot(fitted_model_2.history['accuracy'], c = 'green', label = 'train_acc')
plt.plot(fitted_model_2.history['val_accuracy'], c = 'red', label = 'val_acc')
plt.title('model-2 accuracy')
plt.ylabel('accuracy')
plt.legend()
plt.xlabel('epoch')

plt.subplot(122)
# summarize history for loss
plt.plot(fitted_model_2.history['loss'], label = 'train_loss')
plt.plot(fitted_model_2.history['val_loss'], label = 'val_loss')
plt.title('model-2 loss')
plt.ylabel('loss')
plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
print("Mean val acc:", np.mean(fitted_model_2.history['val_accuracy']))
print("Mean val loss:", np.mean(fitted_model_2.history['val_loss']))
print("Mean train acc:", np.mean(fitted_model_2.history['accuracy']))
print("Mean train loss:", np.mean(fitted_model_2.history['loss']))
# Out:
# Mean val acc: 0.8797396328300238
# Mean val loss: 0.345234889537096
# Mean train acc: 0.8810983076691628
# Mean train loss: 0.3502652971073985

# %%
# FOR TESTING ON TRAINING SET

# check test set accuracy
results_train = ann_2.predict(X_test_scaled)

pred_values_train= []
for result in results_train:
    entry = [0,0,0]
    index = result.argmax()
    entry[index] = 1
    pred_values_train.append(entry)
    
score = accuracy_score(y_test, pred_values_train)
print("test accuracy for model 2: ", score)
# Out:
# test accuracy for model 2:  0.8832764505119454

# %% [markdown]
# ## ACTIVATION FUNCTION 3: TANH

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow as tf

# INITIALING ANN
ann_3 = tf.keras.models.Sequential()

# ADDING INPUT LAYER AND FIRST HIDDEN LAYER
ann_3.add(tf.keras.layers.Dense(units = 112, activation='tanh'))
ann_3.add(Dropout(0.05))

# ADDING SECOND HIDDEN LAYER
ann_3.add(tf.keras.layers.Dense(units=448, activation='tanh', kernel_regularizer=l2(0.001)))

# ADDING THIRD HIDDEN LAYER
ann_3.add(tf.keras.layers.Dense(units=56, activation='tanh'))

# ADDING OUTPUT LAYER
ann_3.add(tf.keras.layers.Dense(units=3, activation='softmax'))

ann_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='val_loss', patience = 10)

fitted_model_31 = ann_3.fit(X_train_scaled, y_train, validation_split = 0.15, callbacks = [callback], epochs= 400, verbose=1)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Layer dense_8 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 351/351 [==============================] - 1s 3ms/step - loss: 0.5719 - accuracy: 0.8347 - val_loss: 0.4828 - val_accuracy: 0.8701
# Epoch 2/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.4265 - accuracy: 0.8797 - val_loss: 0.3942 - val_accuracy: 0.8847
# Epoch 3/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3702 - accuracy: 0.8887 - val_loss: 0.3503 - val_accuracy: 0.8822
# Epoch 4/400
# 351/351 [==============================] - 1s 1ms/step - loss: 0.3354 - accuracy: 0.8952 - val_loss: 0.3099 - val_accuracy: 0.9070
# Epoch 5/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3179 - accuracy: 0.8972 - val_loss: 0.2928 - val_accuracy: 0.9029
# Epoch 6/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3016 - accuracy: 0.9017 - val_loss: 0.3136 - val_accuracy: 0.8953
# Epoch 7/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2921 - accuracy: 0.9006 - val_loss: 0.2943 - val_accuracy: 0.8964
# Epoch 8/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2868 - accuracy: 0.8989 - val_loss: 0.2670 - val_accuracy: 0.9070
# Epoch 9/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2811 - accuracy: 0.9041 - val_loss: 0.2915 - val_accuracy: 0.8969
# Epoch 10/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2798 - accuracy: 0.9048 - val_loss: 0.2630 - val_accuracy: 0.9075
# Epoch 11/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2715 - accuracy: 0.9076 - val_loss: 0.2606 - val_accuracy: 0.9135
# Epoch 12/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2727 - accuracy: 0.9083 - val_loss: 0.2734 - val_accuracy: 0.9024
# Epoch 13/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2705 - accuracy: 0.9076 - val_loss: 0.2806 - val_accuracy: 0.9050
# Epoch 14/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2713 - accuracy: 0.9052 - val_loss: 0.2779 - val_accuracy: 0.9029
# Epoch 15/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2644 - accuracy: 0.9079 - val_loss: 0.2557 - val_accuracy: 0.9080
# Epoch 16/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2656 - accuracy: 0.9063 - val_loss: 0.2526 - val_accuracy: 0.9120
# Epoch 17/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2685 - accuracy: 0.9076 - val_loss: 0.2584 - val_accuracy: 0.9120
# Epoch 18/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2631 - accuracy: 0.9102 - val_loss: 0.2967 - val_accuracy: 0.8928
# Epoch 19/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2630 - accuracy: 0.9083 - val_loss: 0.2800 - val_accuracy: 0.9024
# Epoch 20/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2648 - accuracy: 0.9103 - val_loss: 0.2864 - val_accuracy: 0.8994
# Epoch 21/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2629 - accuracy: 0.9083 - val_loss: 0.2638 - val_accuracy: 0.9110
# Epoch 22/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2600 - accuracy: 0.9130 - val_loss: 0.2477 - val_accuracy: 0.9161
# Epoch 23/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2575 - accuracy: 0.9118 - val_loss: 0.2490 - val_accuracy: 0.9105
# Epoch 24/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2590 - accuracy: 0.9091 - val_loss: 0.2634 - val_accuracy: 0.9095
# Epoch 25/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2569 - accuracy: 0.9117 - val_loss: 0.2533 - val_accuracy: 0.9085
# Epoch 26/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2568 - accuracy: 0.9128 - val_loss: 0.2564 - val_accuracy: 0.9095
# Epoch 27/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2580 - accuracy: 0.9088 - val_loss: 0.2627 - val_accuracy: 0.9039
# Epoch 28/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2520 - accuracy: 0.9129 - val_loss: 0.2567 - val_accuracy: 0.9075
# Epoch 29/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2569 - accuracy: 0.9104 - val_loss: 0.2482 - val_accuracy: 0.9125
# Epoch 30/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2545 - accuracy: 0.9132 - val_loss: 0.2491 - val_accuracy: 0.9125
# Epoch 31/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2536 - accuracy: 0.9117 - val_loss: 0.2589 - val_accuracy: 0.9065
# Epoch 32/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2522 - accuracy: 0.9131 - val_loss: 0.2464 - val_accuracy: 0.9130
# Epoch 33/400
# 351/351 [==============================] - 1s 1ms/step - loss: 0.2554 - accuracy: 0.9125 - val_loss: 0.2563 - val_accuracy: 0.9105
# Epoch 34/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.9123 - val_loss: 0.2557 - val_accuracy: 0.9120
# Epoch 35/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2523 - accuracy: 0.9109 - val_loss: 0.2440 - val_accuracy: 0.9125
# Epoch 36/400
# 351/351 [==============================] - 0s 1ms/step - loss: 0.2548 - accuracy: 0.9119 - val_loss: 0.2514 - val_accuracy: 0.9085
# Epoch 37/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2514 - accuracy: 0.9126 - val_loss: 0.2492 - val_accuracy: 0.9146
# Epoch 38/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2533 - accuracy: 0.9136 - val_loss: 0.2774 - val_accuracy: 0.9070
# Epoch 39/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2479 - accuracy: 0.9162 - val_loss: 0.2496 - val_accuracy: 0.9146
# Epoch 40/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2512 - accuracy: 0.9135 - val_loss: 0.2466 - val_accuracy: 0.9080
# Epoch 41/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2489 - accuracy: 0.9145 - val_loss: 0.2670 - val_accuracy: 0.9060
# Epoch 42/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2482 - accuracy: 0.9134 - val_loss: 0.2537 - val_accuracy: 0.9135
# Epoch 43/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2480 - accuracy: 0.9141 - val_loss: 0.2501 - val_accuracy: 0.9080
# Epoch 44/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2514 - accuracy: 0.9115 - val_loss: 0.2502 - val_accuracy: 0.9075
# Epoch 45/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2473 - accuracy: 0.9152 - val_loss: 0.2634 - val_accuracy: 0.9125

# %%
ann_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 112)               5824
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 112)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 448)               50624
# _________________________________________________________________
# dense_10 (Dense)             (None, 56)                25144
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 171
# =================================================================
# Total params: 81,763
# Trainable params: 81,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig = plt.figure(figsize=(18,5))
# summarize history for accuracy
plt.subplot(121)
plt.plot(fitted_model_31.history['accuracy'], c = 'green', label = 'train_acc')
plt.plot(fitted_model_31.history['val_accuracy'], c = 'red', label = 'val_acc')
plt.title('model-1 accuracy')
plt.ylabel('accuracy')
plt.legend()
plt.xlabel('epoch')

plt.subplot(122)
# summarize history for loss
plt.plot(fitted_model_31.history['loss'], label = 'train_loss')
plt.plot(fitted_model_31.history['val_loss'], label = 'val_loss')
plt.title('model-1 loss')
plt.ylabel('loss')
plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
print("Mean val acc:", np.mean(fitted_model_31.history['val_accuracy']))
print("Mean val loss:", np.mean(fitted_model_31.history['val_loss']))
print("Mean train acc:", np.mean(fitted_model_31.history['accuracy']))
print("Mean train loss:", np.mean(fitted_model_31.history['loss']))
# Out:
# Mean val acc: 0.9057072281837464
# Mean val loss: 0.27448501123322383
# Mean train acc: 0.9065326253573099
# Mean train loss: 0.27733223934968315

# %%
# FOR TESTING ON TRAINING SET

# check test set accuracy
results_train_31 = ann_3.predict(X_test_scaled)

pred_values_train= []
for result in results_train_31:
    entry = [0,0,0]
    index = result.argmax()
    entry[index] = 1
    pred_values_train.append(entry)
    
score = accuracy_score(y_test, pred_values_train)
print("test accuracy for model 3: ", score)
# Out:
# test accuracy for model 3:  0.9010238907849829

# %% [markdown]
# ## ACTIVATION FUNCTION 4: LEAKY RELU AT ALPHA (0.01)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow as tf
from tensorflow.keras.layers import LeakyReLU
leaky_relu = LeakyReLU(alpha=0.01)

# INITIALING ANN
ann_4 = tf.keras.models.Sequential()

# ADDING INPUT LAYER AND FIRST HIDDEN LAYER
ann_4.add(tf.keras.layers.Dense(units = 112, activation = leaky_relu))
ann_4.add(Dropout(0.05))

# ADDING SECOND HIDDEN LAYER
ann_4.add(tf.keras.layers.Dense(units=448, activation = leaky_relu, kernel_regularizer=l2(0.001)))

# ADDING THIRD HIDDEN LAYER
ann_4.add(tf.keras.layers.Dense(units=56, activation = leaky_relu))

# ADDING OUTPUT LAYER
ann_4.add(tf.keras.layers.Dense(units=3, activation='softmax'))

ann_4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='val_loss', patience = 10)

fitted_model_4 = ann_4.fit(X_train_scaled, y_train, validation_split = 0.15, callbacks = [callback], epochs= 400, verbose=1)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Layer dense_12 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 351/351 [==============================] - 1s 2ms/step - loss: 0.5578 - accuracy: 0.8206 - val_loss: 0.4069 - val_accuracy: 0.8777
# Epoch 2/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3929 - accuracy: 0.8775 - val_loss: 0.3633 - val_accuracy: 0.8852
# Epoch 3/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3524 - accuracy: 0.8900 - val_loss: 0.3265 - val_accuracy: 0.8933
# Epoch 4/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3243 - accuracy: 0.8966 - val_loss: 0.2960 - val_accuracy: 0.9029
# Epoch 5/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3089 - accuracy: 0.8972 - val_loss: 0.3138 - val_accuracy: 0.8959
# Epoch 6/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2991 - accuracy: 0.9019 - val_loss: 0.3403 - val_accuracy: 0.8782
# Epoch 7/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2866 - accuracy: 0.9048 - val_loss: 0.2743 - val_accuracy: 0.9075
# Epoch 8/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2838 - accuracy: 0.9029 - val_loss: 0.2774 - val_accuracy: 0.9029
# Epoch 9/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2721 - accuracy: 0.9099 - val_loss: 0.2737 - val_accuracy: 0.9009
# Epoch 10/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2712 - accuracy: 0.9070 - val_loss: 0.2661 - val_accuracy: 0.9075
# Epoch 11/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2637 - accuracy: 0.9121 - val_loss: 0.2660 - val_accuracy: 0.9075
# Epoch 12/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2599 - accuracy: 0.9103 - val_loss: 0.2646 - val_accuracy: 0.9060
# Epoch 13/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2575 - accuracy: 0.9130 - val_loss: 0.2843 - val_accuracy: 0.9024
# Epoch 14/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2578 - accuracy: 0.9099 - val_loss: 0.2563 - val_accuracy: 0.9090
# Epoch 15/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2515 - accuracy: 0.9132 - val_loss: 0.2679 - val_accuracy: 0.9060
# Epoch 16/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2549 - accuracy: 0.9125 - val_loss: 0.2491 - val_accuracy: 0.9146
# Epoch 17/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2533 - accuracy: 0.9131 - val_loss: 0.2621 - val_accuracy: 0.9105
# Epoch 18/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2488 - accuracy: 0.9162 - val_loss: 0.2989 - val_accuracy: 0.8953
# Epoch 19/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2489 - accuracy: 0.9155 - val_loss: 0.2871 - val_accuracy: 0.8964
# Epoch 20/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2466 - accuracy: 0.9170 - val_loss: 0.2723 - val_accuracy: 0.9060
# Epoch 21/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2477 - accuracy: 0.9135 - val_loss: 0.2743 - val_accuracy: 0.9004
# Epoch 22/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2444 - accuracy: 0.9144 - val_loss: 0.2575 - val_accuracy: 0.9090
# Epoch 23/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2448 - accuracy: 0.9153 - val_loss: 0.2520 - val_accuracy: 0.9085
# Epoch 24/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2421 - accuracy: 0.9176 - val_loss: 0.2757 - val_accuracy: 0.9004
# Epoch 25/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2429 - accuracy: 0.9159 - val_loss: 0.2620 - val_accuracy: 0.9034
# Epoch 26/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2379 - accuracy: 0.9189 - val_loss: 0.2546 - val_accuracy: 0.9085

# %%
ann_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 112)               5824
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 112)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 448)               50624
# _________________________________________________________________
# dense_14 (Dense)             (None, 56)                25144
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 171
# =================================================================
# Total params: 81,763
# Trainable params: 81,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig = plt.figure(figsize=(18,5))
# summarize history for accuracy
plt.subplot(121)
plt.plot(fitted_model_4.history['accuracy'], c = 'green', label = 'train_acc')
plt.plot(fitted_model_4.history['val_accuracy'], c = 'red', label = 'val_acc')
plt.title('model-1 accuracy')
plt.ylabel('accuracy')
plt.legend()
plt.xlabel('epoch')

plt.subplot(122)
# summarize history for loss
plt.plot(fitted_model_4.history['loss'], label = 'train_loss')
plt.plot(fitted_model_4.history['val_loss'], label = 'val_loss')
plt.title('model-1 loss')
plt.ylabel('loss')
plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
print("Mean val acc:", np.mean(fitted_model_4.history['val_accuracy']))
print("Mean val loss:", np.mean(fitted_model_4.history['val_loss']))
print("Mean train acc:", np.mean(fitted_model_4.history['accuracy']))
print("Mean train loss:", np.mean(fitted_model_4.history['loss']))
# Out:
# Mean val acc: 0.9013766806859237
# Mean val loss: 0.28549065039708066
# Mean train acc: 0.9052652602012341
# Mean train loss: 0.28275744445048845

# %%
# FOR TESTING ON TRAINING SET

# check test set accuracy
results_train_4 = ann_4.predict(X_test_scaled)

pred_values_train= []
for result in results_train_4:
    entry = [0,0,0]
    index = result.argmax()
    entry[index] = 1
    pred_values_train.append(entry)
    
from sklearn.metrics import confusion_matrix, accuracy_score

score = accuracy_score(y_test, pred_values_train)
print("test accuracy for model 4: ", score)
# Out:
# test accuracy for model 4:  0.9058020477815699

# %% [markdown]
# ## ACTIVATION FUNCTION 5: ELU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow as tf
from tensorflow.keras.layers import LeakyReLU

# INITIALING ANN
ann_5 = tf.keras.models.Sequential()

# ADDING INPUT LAYER AND FIRST HIDDEN LAYER
ann_5.add(tf.keras.layers.Dense(units = 112, activation = 'elu'))
ann_5.add(Dropout(0.05))

# ADDING SECOND HIDDEN LAYER
ann_5.add(tf.keras.layers.Dense(units=448, activation = 'elu', kernel_regularizer=l2(0.001)))

# ADDING THIRD HIDDEN LAYER
ann_5.add(tf.keras.layers.Dense(units=56, activation = 'elu'))

# ADDING OUTPUT LAYER
ann_5.add(tf.keras.layers.Dense(units=3, activation='softmax'))

ann_5.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='val_loss', patience = 10)

fitted_model_5 = ann_5.fit(X_train_scaled, y_train, validation_split = 0.15, callbacks = [callback], epochs= 400, verbose=1)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Layer dense_16 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 341/351 [============================>.] - ETA: 0s - loss: 0.5778 - accuracy: 0.8328WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 351/351 [==============================] - 1s 3ms/step - loss: 0.5743 - accuracy: 0.8341 - val_loss: 0.4480 - val_accuracy: 0.8847
# Epoch 2/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.4291 - accuracy: 0.8804 - val_loss: 0.4002 - val_accuracy: 0.8888
# Epoch 3/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3700 - accuracy: 0.8945 - val_loss: 0.3446 - val_accuracy: 0.8837
# Epoch 4/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3420 - accuracy: 0.8928 - val_loss: 0.3094 - val_accuracy: 0.9039
# Epoch 5/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3217 - accuracy: 0.8983 - val_loss: 0.2970 - val_accuracy: 0.8979
# Epoch 6/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3083 - accuracy: 0.8993 - val_loss: 0.3186 - val_accuracy: 0.8923
# Epoch 7/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2900 - accuracy: 0.9037 - val_loss: 0.2755 - val_accuracy: 0.9100
# Epoch 8/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2856 - accuracy: 0.9027 - val_loss: 0.2730 - val_accuracy: 0.9050
# Epoch 9/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2795 - accuracy: 0.9047 - val_loss: 0.2899 - val_accuracy: 0.8969
# Epoch 10/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2827 - accuracy: 0.9021 - val_loss: 0.2755 - val_accuracy: 0.9009
# Epoch 11/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2691 - accuracy: 0.9093 - val_loss: 0.2629 - val_accuracy: 0.9075
# Epoch 12/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2730 - accuracy: 0.9073 - val_loss: 0.2610 - val_accuracy: 0.9080
# Epoch 13/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2689 - accuracy: 0.9096 - val_loss: 0.2843 - val_accuracy: 0.9024
# Epoch 14/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2678 - accuracy: 0.9058 - val_loss: 0.2706 - val_accuracy: 0.9050
# Epoch 15/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2623 - accuracy: 0.9088 - val_loss: 0.2632 - val_accuracy: 0.9044
# Epoch 16/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2626 - accuracy: 0.9077 - val_loss: 0.2578 - val_accuracy: 0.9050
# Epoch 17/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2634 - accuracy: 0.9107 - val_loss: 0.2617 - val_accuracy: 0.9125
# Epoch 18/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2635 - accuracy: 0.9074 - val_loss: 0.2874 - val_accuracy: 0.8933
# Epoch 19/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2580 - accuracy: 0.9106 - val_loss: 0.2767 - val_accuracy: 0.9014
# Epoch 20/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2603 - accuracy: 0.9109 - val_loss: 0.2845 - val_accuracy: 0.8984
# Epoch 21/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2594 - accuracy: 0.9089 - val_loss: 0.2550 - val_accuracy: 0.9100
# Epoch 22/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2577 - accuracy: 0.9113 - val_loss: 0.2472 - val_accuracy: 0.9130
# Epoch 23/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2551 - accuracy: 0.9121 - val_loss: 0.2466 - val_accuracy: 0.9115
# Epoch 24/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2571 - accuracy: 0.9100 - val_loss: 0.2549 - val_accuracy: 0.9085
# Epoch 25/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2540 - accuracy: 0.9130 - val_loss: 0.2548 - val_accuracy: 0.9070
# Epoch 26/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2536 - accuracy: 0.9132 - val_loss: 0.2559 - val_accuracy: 0.9105
# Epoch 27/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2546 - accuracy: 0.9104 - val_loss: 0.2632 - val_accuracy: 0.9014
# Epoch 28/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2514 - accuracy: 0.9120 - val_loss: 0.2498 - val_accuracy: 0.9100
# Epoch 29/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2536 - accuracy: 0.9119 - val_loss: 0.2490 - val_accuracy: 0.9105
# Epoch 30/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2516 - accuracy: 0.9127 - val_loss: 0.2457 - val_accuracy: 0.9141
# Epoch 31/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2508 - accuracy: 0.9116 - val_loss: 0.2619 - val_accuracy: 0.9100
# Epoch 32/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2520 - accuracy: 0.9143 - val_loss: 0.2414 - val_accuracy: 0.9100
# Epoch 33/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2528 - accuracy: 0.9118 - val_loss: 0.2524 - val_accuracy: 0.9080
# Epoch 34/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2491 - accuracy: 0.9138 - val_loss: 0.2577 - val_accuracy: 0.9095
# Epoch 35/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2525 - accuracy: 0.9103 - val_loss: 0.2445 - val_accuracy: 0.9110
# Epoch 36/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2540 - accuracy: 0.9122 - val_loss: 0.2464 - val_accuracy: 0.9125
# Epoch 37/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2473 - accuracy: 0.9139 - val_loss: 0.2478 - val_accuracy: 0.9100
# Epoch 38/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2516 - accuracy: 0.9123 - val_loss: 0.2657 - val_accuracy: 0.9070
# Epoch 39/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2446 - accuracy: 0.9172 - val_loss: 0.2565 - val_accuracy: 0.9024
# Epoch 40/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2500 - accuracy: 0.9153 - val_loss: 0.2470 - val_accuracy: 0.9110
# Epoch 41/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2450 - accuracy: 0.9150 - val_loss: 0.2703 - val_accuracy: 0.9055
# Epoch 42/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2483 - accuracy: 0.9134 - val_loss: 0.2488 - val_accuracy: 0.9125

# %%
fig = plt.figure(figsize=(18,5))
# summarize history for accuracy
plt.subplot(121)
plt.plot(fitted_model_5.history['accuracy'], c = 'green', label = 'train_acc')
plt.plot(fitted_model_5.history['val_accuracy'], c = 'red', label = 'val_acc')
plt.title('model-1 accuracy')
plt.ylabel('accuracy')
plt.legend()
plt.xlabel('epoch')

plt.subplot(122)
# summarize history for loss
plt.plot(fitted_model_5.history['loss'], label = 'train_loss')
plt.plot(fitted_model_5.history['val_loss'], label = 'val_loss')
plt.title('model-1 loss')
plt.ylabel('loss')
plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
print("Mean val acc:", np.mean(fitted_model_5.history['val_accuracy']))
print("Mean val loss:", np.mean(fitted_model_5.history['val_loss']))
print("Mean train acc:", np.mean(fitted_model_5.history['accuracy']))
print("Mean train loss:", np.mean(fitted_model_5.history['loss']))
# Out:
# Mean val acc: 0.904954500141598
# Mean val loss: 0.27391174080825986
# Mean train acc: 0.906605988740921
# Mean train loss: 0.278056705281848

# %%
# FOR TESTING ON TRAINING SET

# check test set accuracy
results_train_5 = ann_5.predict(X_test_scaled)

pred_values_train= []
for result in results_train_5:
    entry = [0,0,0]
    index = result.argmax()
    entry[index] = 1
    pred_values_train.append(entry)
    
from sklearn.metrics import confusion_matrix, accuracy_score

score = accuracy_score(y_test, pred_values_train)
print("test accuracy for model 5: ", score)
# Out:
# test accuracy for model 5:  0.9010238907849829

# %% [markdown]
# ## ACTIVATION FUNCTION 6: SELU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow as tf
from tensorflow.keras.layers import LeakyReLU

# INITIALING ANN
ann_6 = tf.keras.models.Sequential()

# ADDING INPUT LAYER AND FIRST HIDDEN LAYER
ann_6.add(tf.keras.layers.Dense(units = 112, activation='selu', kernel_initializer='lecun_normal'))
ann_6.add(Dropout(0.05))

# ADDING SECOND HIDDEN LAYER
ann_6.add(tf.keras.layers.Dense(units=448, activation='selu', kernel_initializer='lecun_normal', kernel_regularizer=l2(0.001)))

# ADDING THIRD HIDDEN LAYER
ann_6.add(tf.keras.layers.Dense(units=56, activation='selu', kernel_initializer='lecun_normal'))

# ADDING OUTPUT LAYER
ann_6.add(tf.keras.layers.Dense(units=3, activation='softmax'))

ann_6.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='val_loss', patience = 10)

fitted_model_6 = ann_6.fit(X_train_scaled, y_train, validation_split = 0.15, callbacks = [callback], epochs= 400, verbose=1)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Layer dense_20 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 351/351 [==============================] - 1s 3ms/step - loss: 0.8436 - accuracy: 0.8280 - val_loss: 0.7032 - val_accuracy: 0.8605
# Epoch 2/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.6275 - accuracy: 0.8711 - val_loss: 0.5720 - val_accuracy: 0.8787
# Epoch 3/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.5093 - accuracy: 0.8881 - val_loss: 0.4881 - val_accuracy: 0.8782
# Epoch 4/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.4379 - accuracy: 0.8911 - val_loss: 0.3937 - val_accuracy: 0.9014
# Epoch 5/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3914 - accuracy: 0.8970 - val_loss: 0.3521 - val_accuracy: 0.9039
# Epoch 6/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3619 - accuracy: 0.8971 - val_loss: 0.3569 - val_accuracy: 0.8923
# Epoch 7/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3291 - accuracy: 0.9014 - val_loss: 0.3150 - val_accuracy: 0.9065
# Epoch 8/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3140 - accuracy: 0.8996 - val_loss: 0.3066 - val_accuracy: 0.9014
# Epoch 9/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.3007 - accuracy: 0.9046 - val_loss: 0.3109 - val_accuracy: 0.8953
# Epoch 10/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2965 - accuracy: 0.9039 - val_loss: 0.2956 - val_accuracy: 0.9009
# Epoch 11/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2839 - accuracy: 0.9067 - val_loss: 0.2753 - val_accuracy: 0.9070
# Epoch 12/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2849 - accuracy: 0.9060 - val_loss: 0.2729 - val_accuracy: 0.9075
# Epoch 13/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2782 - accuracy: 0.9064 - val_loss: 0.2768 - val_accuracy: 0.9050
# Epoch 14/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2759 - accuracy: 0.9034 - val_loss: 0.2886 - val_accuracy: 0.8989
# Epoch 15/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2686 - accuracy: 0.9067 - val_loss: 0.2716 - val_accuracy: 0.9050
# Epoch 16/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2671 - accuracy: 0.9077 - val_loss: 0.2558 - val_accuracy: 0.9100
# Epoch 17/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2690 - accuracy: 0.9083 - val_loss: 0.2655 - val_accuracy: 0.9095
# Epoch 18/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2654 - accuracy: 0.9068 - val_loss: 0.2914 - val_accuracy: 0.8938
# Epoch 19/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2610 - accuracy: 0.9107 - val_loss: 0.2759 - val_accuracy: 0.9050
# Epoch 20/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2623 - accuracy: 0.9107 - val_loss: 0.2993 - val_accuracy: 0.8953
# Epoch 21/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2619 - accuracy: 0.9093 - val_loss: 0.2558 - val_accuracy: 0.9115
# Epoch 22/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2568 - accuracy: 0.9108 - val_loss: 0.2452 - val_accuracy: 0.9141
# Epoch 23/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2577 - accuracy: 0.9130 - val_loss: 0.2527 - val_accuracy: 0.9141
# Epoch 24/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2600 - accuracy: 0.9109 - val_loss: 0.2644 - val_accuracy: 0.9050
# Epoch 25/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2548 - accuracy: 0.9126 - val_loss: 0.2549 - val_accuracy: 0.9100
# Epoch 26/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2554 - accuracy: 0.9126 - val_loss: 0.2589 - val_accuracy: 0.9100
# Epoch 27/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2561 - accuracy: 0.9094 - val_loss: 0.2525 - val_accuracy: 0.9095
# Epoch 28/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2494 - accuracy: 0.9144 - val_loss: 0.2561 - val_accuracy: 0.9090
# Epoch 29/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2571 - accuracy: 0.9109 - val_loss: 0.2473 - val_accuracy: 0.9120
# Epoch 30/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2501 - accuracy: 0.9131 - val_loss: 0.2487 - val_accuracy: 0.9156
# Epoch 31/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2528 - accuracy: 0.9110 - val_loss: 0.2545 - val_accuracy: 0.9080
# Epoch 32/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2518 - accuracy: 0.9146 - val_loss: 0.2399 - val_accuracy: 0.9105
# Epoch 33/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2533 - accuracy: 0.9120 - val_loss: 0.2604 - val_accuracy: 0.9085
# Epoch 34/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2481 - accuracy: 0.9137 - val_loss: 0.2604 - val_accuracy: 0.9105
# Epoch 35/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2559 - accuracy: 0.9114 - val_loss: 0.2521 - val_accuracy: 0.9080
# Epoch 36/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2534 - accuracy: 0.9111 - val_loss: 0.2485 - val_accuracy: 0.9100
# Epoch 37/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2484 - accuracy: 0.9144 - val_loss: 0.2476 - val_accuracy: 0.9135
# Epoch 38/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2506 - accuracy: 0.9134 - val_loss: 0.2748 - val_accuracy: 0.9095
# Epoch 39/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2445 - accuracy: 0.9151 - val_loss: 0.2529 - val_accuracy: 0.9060
# Epoch 40/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2471 - accuracy: 0.9155 - val_loss: 0.2473 - val_accuracy: 0.9125
# Epoch 41/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2454 - accuracy: 0.9143 - val_loss: 0.2735 - val_accuracy: 0.9050
# Epoch 42/400
# 351/351 [==============================] - 1s 2ms/step - loss: 0.2478 - accuracy: 0.9135 - val_loss: 0.2567 - val_accuracy: 0.9060

# %%
fig = plt.figure(figsize=(18,5))
# summarize history for accuracy
plt.subplot(121)
plt.plot(fitted_model_6.history['accuracy'], c = 'green', label = 'train_acc')
plt.plot(fitted_model_6.history['val_accuracy'], c = 'red', label = 'val_acc')
plt.title('model-1 accuracy')
plt.ylabel('accuracy')
plt.legend()
plt.xlabel('epoch')

plt.subplot(122)
# summarize history for loss
plt.plot(fitted_model_6.history['loss'], label = 'train_loss')
plt.plot(fitted_model_6.history['val_loss'], label = 'val_loss')
plt.title('model-1 loss')
plt.ylabel('loss')
plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
print("Mean val acc:", np.mean(fitted_model_6.history['val_accuracy']))
print("Mean val loss:", np.mean(fitted_model_6.history['val_loss']))
print("Mean train acc:", np.mean(fitted_model_6.history['accuracy']))
print("Mean train loss:", np.mean(fitted_model_6.history['loss']))
# Out:
# Mean val acc: 0.9041600440229688
# Mean val loss: 0.29696079591910046
# Mean train acc: 0.9055309820742834
# Mean train loss: 0.302066812203044

# %%
# FOR TESTING ON TRAINING SET

# check test set accuracy
results_train_6 = ann_6.predict(X_test_scaled)

pred_values_train= []
for result in results_train_6:
    entry = [0,0,0]
    index = result.argmax()
    entry[index] = 1
    pred_values_train.append(entry)
    
from sklearn.metrics import confusion_matrix, accuracy_score

score = accuracy_score(y_test, pred_values_train)
print("test accuracy for model 6: ", score)
# Out:
# test accuracy for model 6:  0.8962457337883959

# %% [markdown]
# <P>Final comparison of results and run time performance are reported in a tabular form in CM3</P>
